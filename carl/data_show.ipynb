# %%
import os
print(os.getcwd())
from skimage.io import imread, imshow
import matplotlib.pyplot as plt
# Out:
# /home/carl/git/CILProject

# %%
img_data = imread('data/road_renovation_test_image')
imshow(img_data)
plt.show()
